# %%
from kaggle.api.kaggle_api_extended import KaggleApi #https://github.com/Kaggle/kaggle-api
import os
import pandas as pd
import spacy
from spacy.matcher import PhraseMatcher
from spacy.util import minibatch
import random

# %%
# Use Kaggle API to download train.csv, test.csv
api = KaggleApi()
api.authenticate()
api.competition_download_files('nlp-getting-started')

# %%
# Unzip files
os.system('unzip *.zip');

# %%
# Read in training set and test set
df_trn=pd.read_csv('train.csv', error_bad_lines=False, warn_bad_lines=False)
df_tst=pd.read_csv('test.csv', error_bad_lines=False, warn_bad_lines=False)

# %%
# hyperparameter placeholders
lemmatized=True
nostopword=True
batch_num=8
epoch_num=10

# %%
# Load the SpaCy model
nlp = spacy.blank("en")

# %%
# Data exploration
df_trn['text'].head(10)
# Out:
# 0    Our Deeds are the Reason of this #earthquake M...
# 1               Forest fire near La Ronge Sask. Canada
# 2    All residents asked to 'shelter in place' are ...
# 3    13,000 people receive #wildfires evacuation or...
# 4    Just got sent this photo from Ruby #Alaska as ...
# 5    #RockyFire Update => California Hwy. 20 closed...
# 6    #flood #disaster Heavy rain causes flash flood...
# 7    I'm on top of the hill and I can see a fire in...
# 8    There's an emergency evacuation happening now ...
# 9    I'm afraid that the tornado is coming to our a...
# Name: text, dtype: object

# %%
# Create keywords list
keywords_list = ["earthquake", "fire", "flood", "emergency", "tornado", "rain", "disaster"]

# Create a list of tokens from keywords list
keywords_tokens_list = [nlp(keyword) for keyword in keywords_list]

# Create the PhraseMatcher object. The tokenizer is the first argument. Use attr = 'LOWER' to make consistent capitalization
matcher = PhraseMatcher(nlp.vocab, attr='LOWER')

# Add the item patterns to the matcher. 
matcher.add("KEYWORDS",           # Just a name for the set of rules we're matching to
           None,                  # Special actions to take on matched words
           *keywords_tokens_list  # (variable number of) objects of the phrases to match
          )

# %%
# Sample text from training set
sample_idx = 7
sample_txt = df_trn['text'].iloc[sample_idx]

# Create the tokenized version of sample_txt
sample_doc = nlp(sample_txt)

# Create a list of lemmatized, non-stop-word tokens for sample_doc
if lemmatized and nostopword:
    token_list = [token.lemma_ for token in sample_doc if (not token.is_stop)]
elif lemmatized:
    token_list = [token.lemma_ for token in sample_doc]
elif nostopword:
    token_list = [token for token in sample_doc if (not token.is_stop)]
else: 
    token_list = [token for token in sample_doc]

# Find matches in the doc
matches = matcher(sample_doc)

print(sample_txt)
print('-------------------------------------------------------------')
for match in matches:
   print(f"found keyword in token number {match[1]}: {sample_doc[match[1]:match[2]]}")
# Out:
# I'm on top of the hill and I can see a fire in the woods...
# -------------------------------------------------------------
# found keyword in token number 12: fire

# %%
# Initialize a matches dictionary {idx: matches_set}
matches_dict = {}

# Use above sample code with df.iterrows() which iterates over a DataFrame rows as (index, Series) pairs
for idx, series in df_trn.iterrows():

    # Text from training set
    txt = df_trn['text'].iloc[idx]

    # Create the tokenized version of txt
    doc = nlp(txt)

    # Create a list of lemmatized, non-stop-word tokens for doc
    if lemmatized and nostopword:
        token_list = [token.lemma_ for token in doc if (not token.is_stop)]
    elif lemmatized:
        token_list = [token.lemma_ for token in doc]
    elif nostopword:
        token_list = [token for token in doc if (not token.is_stop)]
    else: 
        token_list = [token for token in doc]

    # Find matches in the doc
    matches = matcher(doc)
    
    # Create a set of matches found in doc
    matches_set = {doc[start:end] for match_id, start, end in matches}
    
    # Append to matches dictionary
    if len(matches_set) > 0:
        matches_dict.update({idx: matches_set})

# %%
# Load the SpaCy model
nlp = spacy.blank("en")

# Create the TextCategorizer with exclusive classes and "bow" architecture (ngram “bag-of-words”) 
textcat = nlp.create_pipe(
              "textcat",
              config={
                "exclusive_classes": True,
                "architecture": "bow"})

# Add the TextCategorizer to the empty model
nlp.add_pipe(textcat)

# Add labels to text classifier
textcat.add_label('real')
textcat.add_label('not')
# Out:
# 1

# %%
# The model is looking for "real", "not" labels inside another dictionary with the key 'cats'
# e.g. if a text is "real", we need a dictionary {'real': True, 'not': False}
train_texts = df_trn['text'].values
train_labels = [{'cats': {'real': target == 1, 'not': target == 0}} for target in df_trn['target']]

# combine the texts and labels into a single list
train_data = list(zip(train_texts, train_labels))

# %%
# Create an optimizer using nlp.begin_training()
spacy.util.fix_random_seed(1)
optimizer = nlp.begin_training()

losses = {}
random.seed(1)
# loop through the training set epoch_num times, re-shuffling the training data at the begining of each iteration
for epoch in range(epoch_num):
    random.shuffle(train_data)
    # Create the batch generator with batch size = batch_num
    batches = minibatch(train_data, size=batch_num)
    # Iterate through minibatches
    for batch in batches:
        # Each batch is a list of (text, label) but we need to
        # send separate lists for texts and labels to update().
        # This is a quick way to split a list of tuples into lists
        texts, labels = zip(*batch)
        nlp.update(texts, labels, sgd=optimizer, losses=losses)
    # Print accumulated loss bug (HB: FIX THIS)
    print(losses)
# Out:
# {'textcat': 5.311279617191758}
# {'textcat': 8.446476191224065}
# {'textcat': 10.580094419201487}
# {'textcat': 12.142444305991376}
# {'textcat': 13.328999306524565}
# {'textcat': 14.263951404558611}
# {'textcat': 15.022631380922121}
# {'textcat': 15.645888627128897}
# {'textcat': 16.16052245742469}
# {'textcat': 16.598223631826045}

# %%
# Define a function that predicts class for each text, given a model and a list of texts
def predict(model, texts): 
    # Use the model's tokenizer to tokenize each input text
    docs = [model.tokenizer(text) for text in texts]
    
    # Use textcat to get the scores for each doc
    textcat = model.get_pipe('textcat')
    scores, _ = textcat.predict(docs)
    
    # From the scores, find the class with the highest score/probability
    predicted_class = scores.argmax(axis=1)
    
    return predicted_class

# %%
# Make predictions
texts = df_tst['text'].values
predicted_class = predict(nlp, texts)

for p, t in zip(predicted_class, texts):
    print(f"{textcat.labels[p]}: {t} \n")
# Out:
# real: Just happened a terrible car crash
#
# real: Heard about #earthquake is different cities, stay safe everyone.
#
# real: there is a forest fire at spot pond, geese are fleeing across the street, I cannot save them all
#
# real: Apocalypse lighting. #Spokane #wildfires
#
# real: Typhoon Soudelor kills 28 in China and Taiwan
#
# real: We're shaking...It's an earthquake
#
# not: They'd probably still show more life than Arsenal did yesterday, eh? EH?
#
# not: Hey! How are you?
#
# not: What a nice hat?
#
# not: Fuck off!
#
# not: No I don't like cold!
#
# not: NOOOOOOOOO! Don't do that!
#
# not: No don't tell me that!
#
# not: What if?!
#
# not: Awesome!
#
# real: Birmingham Wholesale Market is ablaze BBC News - Fire breaks out at Birmingham's Wholesale Market http://t.co/irWqCEZWEU
#
# not: @sunkxssedharry will you wear shorts for race ablaze ?
#
# real: #PreviouslyOnDoyinTv: Toke MakinwaÛªs marriage crisis sets Nigerian Twitter ablaze... http://t.co/CMghxBa2XI
#
# not: Check these out: http://t.co/rOI2NSmEJJ http://t.co/3Tj8ZjiN21 http://t.co/YDUiXEfIpE http://t.co/LxTjc87KLS #nsfw
#
# not: PSA: IÛªm splitting my personalities.
#
# ?? techies follow @ablaze_co
# ?? Burners follow @ablaze
#
# real: beware world ablaze sierra leone &amp; guap.
#
# not: Burning Man Ablaze! by Turban Diva http://t.co/hodWosAmWS via @Etsy
#
# not: Not a diss song. People will take 1 thing and run with it. Smh it's an eye opener though. He is about 2 set the game ablaze @CyhiThePrynce
#
# real: Rape victim dies as she sets herself ablaze: A 16-year-old girl died of burn injuries as she set herself ablazeÛ_ http://t.co/UK8hNrbOob
#
# not: SETTING MYSELF ABLAZE http://t.co/6vMe7P5XhC
#
# real: @CTVToronto the bins in front of the field by my house wer set ablaze the other day flames went rite up the hydro pole wonder if it was him
#
# not: #nowplaying Alfons - Ablaze 2015 on Puls Radio #pulsradio http://t.co/aA5BJgWfDv
#
# not: 'Burning Rahm': Let's hope City Hall builds a giant wooden mayoral effigy 100 feet tall &amp; sets it ablaze. http://t.co/kFo2mksn6Y @John_Kass
#
# not: @PhilippaEilhart @DhuBlath hurt but her eyes ablaze with insulted anger.
#
# real: Accident cleared in #PaTurnpike on PATP EB between PA-18 and Cranberry slow back to #traffic http://t.co/SL0Oqn0Vyr
#
# not: Just got to love burning your self on a damn curling wand... I swear someone needs to take it away from me cuase I'm just accident prone.
#
# not: I hate badging shit in accident
#
# real: #3: Car Recorder ZeroEdgeå¨ Dual-lens Car Camera Vehicle Traffic/Driving History/Accident Camcorder  Large Re... http://t.co/kKFaSJv6Cj
#
# not: Coincidence Or #Curse? Still #Unresolved Secrets From Past http://t.co/7VG8Df9pLE #accident
#
# real: @Traffic_SouthE @roadpol_east Accident on A27 near Lewes is it Kingston Roundabout rather than A283
#
# not: @sakuma_en If you pretend to feel a certain way the feeling can become genuine all by accident. -Hei (Darker than Black) #manga #anime
#
# real: For Legal and Medical Referral Service @1800_Injured Call us at: 1-800-465-87332 #accident #slipandfall #dogbite
#
# not: There's a construction guy working on the Disney store and he has huge gauges in his ears ?? ...that is a bloody accident waiting to happen
#
# not: @RobynJilllian @WlSDOMTEETHS I feel like I'm going to do it on accident. Teesha is gonna come out??
#
# real: On the #M42 northbound between junctions J3 and J3A there are currently delays of 10 mins due to an accident c... http://t.co/LwI3prBa31
#
# not: @DaveOshry @Soembie So if I say that I met her by accident this week- would you be super jelly Dave? :p
#
# real: ACCIDENT - HIT AND RUN - COLD at 500 BLOCK OF SE VISTA TER GRESHAM OR [Gresham Police #PG15000044357] 10:35 #pdx911
#
# not: @Calum5SOS this happened on accident but I like it http://t.co/QHmXuljSX9
#
# real: Please donate and spread the word! A training accident left the pole-vaulter Kira GrÌ_nberg a paraplegic http://t.co/6MpnyCl8PK
#
# not: Please like and share our new page for our Indoor Trampoline Park Aftershock opening this fall!! http://t.co/UgXhHErrxS
#
# not: @bxckylynch foi no ROH Aftershock: Las Vegas procura no pirate bay que tem
#
# not: Schoolboy ÛÒ Aftershock (Original Mix)
# Excision &amp; Skism ÛÒ SEXisM (Far Too Loud Remix)
# Firebeatz Schella ÛÒ Dear New... http://t.co/JQLzUA6YzQ
#
# not: 320 [IR] ICEMOON [AFTERSHOCK] | http://t.co/THyzOMVWU0 | @djicemoon | #Dubstep #TrapMusic #DnB #EDM #Dance #IcesÛ_ http://t.co/83jOO0xk29
#
# not: 'When the aftershock happened (Nepal) we were the last int'l team still there; in a way we were 1st responders.' Chief Collins @LACo_FD
#
# not: 320 [IR] ICEMOON [AFTERSHOCK] | http://t.co/gRPeF7yAWG | @djicemoon | #Dubstep #TrapMusic #DnB #EDM #Dance #IcesÛ_ http://t.co/GGmvzT58vE
#
# not: Stop saying 'I Wish' and start saying 'I Will'. ÛÒ Unknown
#
# not: I want to go to Aftershock in October because it has all the bands I listen to and #NXT! Can't afford it yet though. #gradschoolapps
#
# real: 'We are still living in the aftershock of Hiroshima people are still the scars of history.' - Edward Bond http://t.co/engTl5wrGp
#
# not: 320 [IR] ICEMOON [AFTERSHOCK] | http://t.co/THyzOMVWU0 | @djicemoon | #Dubstep #TrapMusic #DnB #EDM #Dance #IcesÛ_ http://t.co/83jOO0xk29
#
# not: Aftershock https://t.co/Ecy4U623nO
#
# not: 'There is no victory at bargain basement prices.' Dwight David Eisenhower
#
# not: Bo2 had by far the best competitive maps imo hope bo3 is the same #InVahnWeTrust
#
# real: Brass and Copper in Cataclysm &amp; AfterShock!!! http://t.co/uxYZyaygTy
#
# not: @JadeForMKX You should be happy I don't use Aftershock. That variation counters your play style hard.
#
# not: Aftershock https://t.co/38Nhq9moEf
#
# real: When carelessness leads to an aviation accident the victim has the right to seek compensation for damages. http://t.co/eqAG6rz1vO
#
# not: @rewind_music found out about you guys today(regarding the accident on the airplane lol) &amp; became a fan! Sending love &amp; support from Cali~?
#
# not: A girl who died in an airplane accident fifteen years ago
#
# real: @Mintechan Hihow are you? There is Keio line on the stationright? BTW do you know the airplane accident near Chofu airport this week?
#
# real: Mexican airplane accident in Ocampo Coahuila MX on 7/29/25 killed Coahuila government SubSecretariat Francisco Garcia Castells age 42.
#
# real: Horrible Accident  Man Died In Wings of AirplaneåÊ(29-07-2015) http://t.co/5ZRKZdhODe
#
# not: @god if an accident were to happen on this airplane idc if the rest of my luggage is completely destroyed just please save my makeup
#
# real: Horrible Accident Man Died In Wings of Airplane (29-07-2015) http://t.co/hG8u2kR1Rq
#
# real: #UPDATE: Picture from the Penn Twp. airplane accident. http://t.co/6JfgDnZRlC
#
# not: See how a judge ruled in this 2009 accident at #JFK Airport? involving Korean Air?.
#
# http://t.co/Yh1cGlN3rl http://t.co/6F5ShPKjOB
#
# not: @thugIauren I had myself on airplane mode by accident ??
#
# real: 36 years ago today baseball lost one of its greats in an airplane accident. RIP Captain. #Yankees @yankees http://t.co/iNKU28vjJj
#
# real: Experts in France begin examining airplane debris found on Reunion Island: French air accident experts on Wedn... http://t.co/miw2i0pQxz
#
# real: #BreakingNews Experts in France begin examining airplane debris found on Reunion Island: French air accident e...  http://t.co/3XIcUvlvlJ
#
# real: Experts in France begin examining airplane debris found on Reunion Island: French air accident experts on Wedn...  http://t.co/KuBsM16OuD
#
# real: Twelve feared killed in Pakistani air ambulance helicopter crash http://t.co
# not: $GMCR no longe rGreen mountain now Red Mountain...stock annihilated after hours
#
# not: Please sign &amp; RT to save #SaltRiverWildHorses http://t.co/GB8ispiaRP http://t.co/Bx0l87iNc8
#
# not: Allied Plans for the Annihilation of the German People http://t.co/RUHxGlo18q
# http://t.co/HbUpkzWdWq
# Louis Nizer - Very interesting...
#
# not: Please share and sign this petition to save wild horses in Arizona. http://t.co/3tsSXPHuFE
#
# not: U.S National Park Services Tonto National Forest: Stop the Annihilation of the Salt River Wild Horse... https://t.co/lATVr8RZCK via @Change
#
# not: NEW! Are souls punished with annihilation? http://t.co/cmNV6VyFCQ
#
# not: ***Latest Updates on the Salt River Wild Horse Round-up*** https://t.co/WJsCdvCevH via @Change
#
# not: U.S National Park Services Tonto National Forest: Stop the Annihilation of the Salt River Wild Horse... https://t.co/W5Rhtuey90 via @Change
#
# not: U.S National Park Services Tonto National Forest: Stop the Annihilation of the Salt River Wild Horse... https://t.co/ZhXua8kmae via @Change
#
# not: @BosTeenAuthFest Out of the Silent Planet in print and Annihilation on audio.
#
# real: RT SIGN URGENT Stop the Annihilation of the Salt River Wild Horses!!! #savewildhorses #saltriverhorses https://t.co/8AZjFF8eSi
#
# not: @jackienatalydlt I do.... I only get the iced annihilation??
#
# not: U.S National Park Services Tonto National Forest: Stop the Annihilation of the Salt River Wild Horse... https://t.co/d82wlcP49S via @Change
#
# not: U.S National Park Services Tonto National Forest: Stop the Annihilation of the Salt River Wild Horse... https://t.co/KAlDycTC4H via @Change
#
# not: @INCIndia under Sonia Gandhi is like Pakistan. Every defeat is treated like a victory.Total annihilation only answer
# http://t.co/KtTYiTOw64
#
# not: U.S National Park Services Tonto National Forest: Stop the Annihilation of the Salt River Wild Horse... http://t.co/TrKg2tpWJm via @Change
#
# not: U.S National Park Services Tonto National Forest: Stop the Annihilation of the Salt River Wild Horse... http://t.co/k0q4fnBzss via @Change
#
# real: Stop the Annihilation of the Salt River Wild Horses!!! https://t.co/546utTXzAm via @Change
#
# not: U.S National Park Services Tonto National Forest: Stop the Annihilation of the Salt River Wild Horse... https://t.co/FLcQQeZnVW via @Change
#
# not: U.S National Park Services Tonto National Forest: Stop the Annihilation of the Salt River Wild Horse... https://t.co/FaXDzI90dY via @Change
#
# not: U.S National Park Services Tonto National Forest: Stop the Annihilation of the Salt River Wild Horse... https://t.co/n6VeOjW3S8 via @Change
#
# not: U.S National Park Services Tonto National Forest: Stop the Annihilation of the Salt River Wild Horse... https://t.co/i0z3k0chgg via @Change
#
# not: @spherulitic that almost feels like the SI signs of the apocalypse.  Lol.
#
# not: I liked a @YouTube video from @teamtwiistz http://t.co/OCurjyDRcn FUTURISTIC HOUSE (Built To Survive The Apocalypse!) - Minecraft
#
# not: I liked a @YouTube video http://t.co/jrFjgaAc9F Minecraft: NIGHT LUCKY BLOCK MOD (BOB APOCALYPSE WITHER 2.0 &amp; MORE!) Mod Showcase
#
# not: @thomasa56 Just ONE of my major reasons not to live in *Big City*. If RR's *miss 9 meals* ever comes to pass Cue ANY 'Apocalypse' script.
#
# not: #AskConnor there's a zombie apocalypse. the item to your right is your weapon. you're either screwed or you're gonna live.
#
# not: It's an apocalypse
#
# not: @ItsKingRiffYall I'm excited for apocalypse really dig how the x-men franchise is going I like the 'event' theme a lot.
#
# not: @TMFK_CO sounds like a terrible time. I'll be right there.
#
# real: Apocalypse no! Why artists should not go into the #Fukushima exclusion zone
# http://t.co/3zqL0qbLUw
# #nuclear #ura
#
# not: Southern Prepper Fiction:Sharecropping the Apocalypse https://t.co/HsleABS1Yr #Apocalyptic #doomsday #prepper #book #reading
#
# not: @5SOStag honestly he could say an apocalypse is coming and i would be exited hes so enthusiastic about everything
#
# not: Also my other nephew is proof that fat babies are going to save us from the apocalypse http://t.co/N5VImOqhBG
#
# not: I liked a @YouTube video http://t.co/2umSxRzot3 Zombie Apocalypse: The Rescue
#
# not: I added a video to a @YouTube playlist http://t.co/OCurjyDRcn FUTURISTIC HOUSE (Built To Survive The Apocalypse!) - Minecraft Maps
#
# not: |LIVE NOW| Princes of the Apocalypse:  D&amp;D Encounters #meerkat http://t.co/oY9ES9FVlt
FedEx no longer to transport bioterror germs in wake of anthrax lab mishaps #breakingnews
#
# real: FedEx no longer to transport bioterror germs in wake of anthrax lab mishaps http://t.co/kA0syAhqVW via @usatoday
#
# real: FedEx no longer to transport bioterror germs in wake of anthrax lab mishaps http://t.co/1CsEBhPLfh via @usatoday
#
# not: Unsurprising/still dismaying consequences of how we went about securing pathogen access: http://t.co/D8EFmGyR2d
#
# real: FedEx no longer to transport bioterror germs in wake of anthrax lab mishaps
#
# http://t.co/SjNKpJ8lEe
#
# #watchcbs19 http://t.co/JiRXfok46c
#
# real: Latest fallout from biolab safety lapses: FedEx no longer will transport anthrax &amp; select agent research specimens http://t.co/4iOOyIbxyo
#
# real: #FedEx no longer to transport #bioterror germs in wake of #anthrax lab mishaps http://t.co/Ziw1RWPJkK
#
# real: FedEx stops shipping potential bioterror pathogens: FedEx Corp. (NYSE: FDX) will no longer deliver packages thatÛ_ http://t.co/CRD6tgIZhG
#
# not: Citizens Education Project has acted for years as a watchdog on the Dugway Proving Grounds. http://t.co/NZHXYapLm0
#
# real: FedEx no longer to transport bioterror germs in wake of anthrax lab mishaps http://t.co/L04Q4DKvue http://t.co/z5voujEus4
#
# not: FedEx no longer will transport bioterror germs http://t.co/9lam19N5i5 via @USATODAY
#
# real: In offbeat news @fedex has stopped shipping bioterror pathogens http://t.co/gvXXidHOlF
#
# not: FedEx no longer to transport bioterror germs in wake of anthrax lab mishaps http://t.co/RghHkWtKLR #newsdict #news  #FedEx
#
# not: Bioterrorism and Ebola. http://t.co/ORIOVftLK4 RT #STOPIslam #TCOT #CCOT #MakeDCListen #TeaParty
#
# real: The largest bioterrorism attack on U.S. soil involved tacos @atlasobscura http://t.co/1n9CRhWmgl
#
# not: Is it time to hedge against catastrophic risks such as climate change asteroid impacts or bioterrorism? https://t.co/HQ6WqsgSJX
#
# real: @USCOURT If 90BLKs&amp;8WHTs colluded 2 take WHT F @USAgov AUTH Hostage&amp;2 make her look BLK w/Bioterrorism&amp;use her lgl/org IDis ID still hers?
#
# real: Bioterrorism : Guidelines for Medical and Public Health Management (2002) http://t.co/zkUXHnoBaG http://t.co/FHgkYxffu5
#
# not: @bbcworld Bioterrorism drones can reach large populated erea.
#
# real: @BishoyRagheb fair. Bioterrorism is the way to go. Does that mean my BSc isn't irrelevant?
#
# real: @DebtAssassin They forget there is the threat of bioterrorism.
#
# not: HST's Anthony Kimery Discusses #BioTerrorism on @Syfy Channel's 'Joe Rogan Questions Everything' #Pathogen #Virus http://t.co/0FDsc3f2IW
#
# not: Anthony Kimery Discusses #BioTerrorism on SyFy Channel's 'Joe Rogan Questions Everything' http://t.co/zckJWAcRCs
#
# real: @HarvardU If 90BLKs&amp;8WHTs colluded 2 take WHT F @USAgov AUTH Hostage&amp;2 make her look BLK w/Bioterrorism&amp;use her lgl/org IDis ID still hers?
#
# not: Uganda Seen as a Front Line in the Bioterrorism Fight
#
# not: Ppl living w/ HIV have been charged with aggravated assault and bioterrorism for things w/ low or no risk of transmission. #HIVIsNotaCrime
#
# not: Studying anthrax and bioterrorism before 7 am ?? #carpediem
#
# real: @GACourts If 90BLKs&amp;8WHTs colluded 2 take WHT F @USAgov AUTH Hostage&amp;2 make her look BLK w/Bioterrorism&amp;use her lgl/org IDis ID still hers?
#
# real: Bioterrorism: Guidelines for Medical and Public Health Management Donald A. Hen http://t.co/tDg0Bsmd6c http://t.co/iirWFZMKHO
# real: #Nepal: This house near TIA bleeding intÛªl airline companies dry. | http://t.co/lI8wi1kuMY
#
# real: @Battlehork I wish I could watch but the gif the LU account posted of Mundo bleeding... Jesus! D:
#
# not: did leona lewis ever see that video of dinah singing bleeding love?
#
# not: @TomBrevoort 'Bleeding Cool as read by Tom Brevoort. Though he may just look at the pictures.'
#
# not: You cut me open and I keep bleeding. #BleedingLove #LeonaLewis #acapella #singer #canadiansingerÛ_ https://t.co/51pfEIlPNK
#
# not: *Ears bleeding from the bass* https://t.co/d5RrrwHjpN
#
# not: @KrisZellner But Triplemania has the promise of Villano bleeding and Del Rio whooping that Trick Myztiziziziziz.
#
# not: Looks like Reynolds and Montano coming in. Need to stop the bleeding. Not the best performance so far.
#
# real: @imKanoMate [the stabbing did not really affect her but she did get stab wounds and was bleeding Skarlet then pushed him backwards +
#
# not: Yeah I hate cats I just tried to pet our own cat and now my hand has bite marks scratch marks and it's bleeding. #DogsAreBetterThanCats
#
# not: @Aichmomanic wraps a cloth on my wound but it's still bleeding 'I'll be ok.' Falls to the ground as if I'm going to die
#
# not: my ears are bleeding  https://t.co/EeVQj37Ndg
#
# not: @dudeandpal it's so bad my eyes and ears are bleeding
#
# not: wouldn't want me to quit even if I was bleeding
#
# not: @idkimnotfunny this quickly blew up and my mom doesn't get why it's so popular
#
# not: LMFAO MY SNAP JUST BLEW UP!
#
# not: Just blew you up @abbss_13 just so I can get that follow back ????
#
# not: @atlwtmgc damn this blew up
#
# not: Wow social media really blew up after the shania twain concert
#
# not: @cieIstea IDK BUT IT BLEW UP
#
# not: * I'm always one phone call away but too many people done blew up they chances with me.
#
# not: well this tweet blew up fast
#
# not: Well this blew up while i was sleeping
#
# not: @funnychubbyguy poor white guy his mom made him pizza and he wanted mac n cheese so he blew up a school. Such a sad story.
#
# not: Wow bro blew up quick. Believe it or not he's this funny and clever in person at all times. You be like 'where... http://t.co/djIHN95YnB
#
# not: @TokyoDotCom I didn't either till it blew up my mentions lol
#
# not: We were fucking around on Google maps at work and I pulled up Boise and it blew their minds. Yeah Idaho isn't what you think at all.?
#
# not: That stadium blew up!!
#
# not: The balloon thing was so rude I would have popped the balloon than whoever blew it up's face
#
# not: @TheFieryGrave yeah true because if he wouldn't have got exposed then he probably wouldn't have went to mlg and blew up there
#
# not: The only reason why player's now have an ego is cause MW3 had cod champs that's when eSports Blew up and now player's strictly look for ORGs
#
# not: THDA Kicks Off Anti-Blight Loan Effort in Memphis http://t.co/7Gf7CpYL0R
#
# not: .@WestmdCountyPA land bank targets first #Latrobe building in 20th property acquisition to fight #blight: http://t.co/regDv873Aj
#
# not: Lots of talk of how susceptible NY2 is to shoot blight with or without trama. #WCFGT2015
#
# not: Help fight Northern Corn Leaf Blight with Headline Amp https://t.co/LVoqPgkLI7
#
# not: @colemcfadyean fuck off cole ??????
#
# real: Imagine if 2 Old Gods were awakened to start a Blight 2.0
# @BioMarkDarrah @Mike_Laidlaw
#
# real: Stamford tightens blight law: A dilapitated barn sits half-erect on Hickory Road near the int... http://t.co/QP65iO4AvC #stamford #topix
#
#
# not: genuine Leather man Bag Messenger fit iPad mini 4 tablet case cross body air jp - Full reaÛ_ http://t.co/Vl26HSrq4E http://t.co/ryl0Y88fKM
#
# not: @MeekMill I think its time you consulted @kendricklamar cause @Drake done body bagging you
#
# not: People are bagging on Rousey's body? Shit I'd love to have a body like that. Those who are ridiculing her are probably dudes in skinny jeans
#
# not: Bagging the last spot on Body Attack ?????? #getin #traintuesday #lesmills
#
# not: ' Dear Lord Forgive Me For Body Bagging @MeekMill Not Once But Twice. Amen ' - @Drake http://t.co/dPBz1PYvFF
#
# not: @cameron13131313 @OtooleDalton @averywelch23 @otoole1055 first of all you can't 'hit stick' shit.. Second I'm body bagging you on sight ??????
#
# not: Drake is really body bagging meek atm
#
# not: I remember the halo interview with ABC. Wasn't no time and The Pamanian Devil was body bagging fools. https://t.co/CpK7300RQg
#
# not: Jersey's artist Wolfgangjoc pays homage to the late great Biggie Smalls by body bagging  his hypnotize beat.... http://t.co/x0jKnOxJHA
#
# not: Not only did Drake kill Meek Mill but he started T bagging his his dead body ????????????
#
# ...
#
# not: @sindy642498
# I'm really glad to hear thatÛ_;;
# Nowlike usthe world is truely connected.
# I want truely peaceful world without any weapon!
#
# not: @JPens4Real21 Geno has weapons now I'll give him the benefit of the doubt this year. I'm just not a huge believer. Still not mature enough.
#
# not: @DANNYonPC @YouTube Its engineer only again so 2 1000+ rpm weapons = no thanks
#
# not: Helpful Tips For Nuking An Asteroid http://t.co/GwRsga9uJV
#
# not: I'm all in favor of keeping dangerous weapons out of the hands of fools. Let's start with typewriters.
#
# real: Security experts report that the only way to keep Iran 'honest' and stop her march to nuclear weapons is by... http://t.co/DGnbUsfXkw
#
# not: Aug 3 1915ÛÓKILL 10000 WITH ROCKS.; Italians Make Good Use of Nature's Weapons -- Excel with Bayonet.
# http://t.co/ck1mMvHU0T
#
# real: @deray @marstu67 Cop Benefits:Great Salary Free Car Free Rent Free Food.Free Weapons License to Kill &amp; Rape with Impunity.
#
# not: ??Water fight??
# Penn park 6pm
#       BYOW
# (Bring Your Own Weapons)
#
# real: Abe proposed a new plan for abolishing nuclear weapons. Yesterday his defense minister made clear nukes are fine. http://t.co/A6IR8rKuwS
#
# real: NAVY SAYS LT CMDR WHO FIRED SIDEARM IN DEFENSE DURING NOSC CHATTANOOGA TERRORIST ATTACK WILL NOT FACE CHARGES... http://t.co/vCcDKC4qt2
#
# real: Any attempt to sell weapons to #Nigeria is an attempt to upgrad #Bokoharm army #USA must know this now @UN
#
# not: Whirlwind full of bombarded kunais.
#
# not: @BarstoolBigCat what a whirlwind.
#
# not: I've officially been a St. Louisan for one full year. What a crazy awesome overwhelming whirlwind year it has been. Here's to another!
#
# real: Missing Malaysian airplane: Debris was planted ÛÒ Families News - WhirlWind News http://t.co/bLd0nHKzbh
#
# not: Warcraft has always been this weird referential whirlwind to itself and other things
#
# not: @Chelsea_Rosette ah bless ya. Not too bad. My life's been a bit of a whirlwind the last two weeks! Got a cold too that won't shift ?? #sexy
#
# not: Join me on FB for #Sneak #Peek Friday http://t.co/3DK5zyYQ1F for my upcoming #novel To Reap a Whirlwind #fiction #historical #wip #amwriting
#
# not: WAS Times: PawSox owners public return from whirlwind trip to Durham http://t.co/07nKMO7VaS
#
# not: I liked a @YouTube video http://t.co/a5YTAw9Vih S.O.S. Rona Guide - The Red Whirlwind
#
# not: [VID]150806 Luhan From Luhan Studio Channel on YOUKU Update
#
# http://t.co/W7yeZkQlCJ http://t.co/C0QWZ0IshR
#
# not: {{ whirlwind romance dress | in-store &amp; online }} #freshoutofthebox #getitbeforeitsgone #under50 #newnewnew... http://t.co/8BUTsC4ZyN
#
# real: #HarperANetflixShow  Blazing Saddles  (a show about wild fires in Alberta)
#
# real: ?? #BREAKING: massive wild- and field fires reported throughout Germany! The most fires are in eastern #German http://t.co/4zSIy7EO2O
#
# real: We all complain about PA but atleast we don't have those wild fires taking our homes like north Cali or the floods in Florida right now
#
# not: my wife has opted to take holidays &amp; historically since we met @lanahillman gets special treatment her bonfires can't start wild fires-RAIN!
#
# not: Like blazing wild fires singing Your name!
#
# real: NetNewsLedger Wild Fire Update ÛÒ August 4 2015: THUNDER BAY ÛÒ WEATHER ÛÒ ThereåÊwere no new fires confirmed by t... http://t.co/JflxgEmBdA
#
# real: @myralynn24 Becuase it can cause property damage and cause wild fires
#
# real: Hey @Macys ! My moms house burned down in the CA wild fires &amp; I bought her an e gift card to buy her CLOTHES (cont) http://t.co/sWdjnypCXK
#
# real: California wild fires...clearly caused by global climate change and excess CO2!!!?
#
# real: California wild fires blow my mind every time
#
# real: @MrRat395 Are those wild fires getting anywhere near you?
#
# real: Stampedes and fires brought him home; can her love make him stay? TAME A WILD HEART #audiobook http://t.co/2dPKqAFtbr #BYNR @BeingAuthor
#
# real: Go home California you're drunk. Natural selection has taken affect. Debt extreme wild fires water supply problems. You fail as a state.
#
# real: @CBS evening news covers tent collapse wild fires NO mention of worst Planned Parenthood video to date #Narrative
#
# not: WILD FIRES! http://t.co/EgrMdkXpOi
#
# real: Wild Fires In California Continue To Burn - http://t.co/nKcmib9WL0 http://t.co/CpMGBWVDXM
#
# real: one of them wild fires in cali or something or in the mid west or where ever they show up..shit dont pop up around me
#
# real: @JacobHoggard @therealmattleaf  it's so sad out there in BC all the wild fires. Hope u are safe.
#
# real: when there's 35 wild fires in the US and 21 of them are in California....AND we're in a drought.....this state is so sad
#
# real: 11:57am Wildfire by The Mynabirds from Lovers Know
#
# real: Finger Rock wildfire grows to 500 acres #Tucson http://t.co/zSXGEI1Nxf
#
# real: #chattanooga The Latest: California governor headed to site of wildfire http://t.co/D6E7IICW5W
#
# real: About to get it with the babes of #wildfire and @taviiikenney of course!!
#
# not: Here's a quick timelapse I made of the Finger Rock Fire last night from about 9PM - 1AM. Check it out! #fingerrockfire #wildfire #catalinas
#
# real: #WAwildfire in #chelan? Wolverine fire results in evacuation. http://t.co/yePlnZPoWu
#
# not: can't eat a wildfire chicken salad without thinking of / missing @Alynacarol ??
#
# real: Cherokee Road and Road 22 (Three Sisters Wildfire): There are two roads closed to the general public: ... http://t.co/WwnL8FvfMM #IDFire
#
# real: Officer Wounded Suspect Killed in Exchange of Gunfire http://t.co/HHSjnAVHUA
#
# real: 'Police Officer Wounded Suspect Dead After Exchanging Shots' http://t.co/guNq7ZTUn4 #????_?????
#
# real: Police Officer Wounded Suspect Dead After Exchanging Shots: Richmond police officer wounded suspect killed a... http://t.co/YIKQRqczVZ
#
# not: He was crushed for our iniquities; the punishment that brought us peace was upon him &amp; by his wounds we are healed. -Isa 53:5
#
# not: @bkanioros Lizeth and I tried over and over again to fix our relationship it never worked bk you cannot heal those wounds I love you for
#
# not: Love wounds
#
# not: '@GoogleFacts: Wounds heal faster if you lick them. Tears also help them heal as well.'  I know right even thou it seems stupid when lickin
#
# real: the wounds of honor
#  are self-inflicted
#
# not: ME: gun shot wounds 3 4 6 7 'rapidly lethal' would have killed in 30-60 seconds or few minutes max. #kerricktrial
#
# not: @Cash7Nigga whoa. Insomniac. Why don't you try to get some sleep. Sleep heals all wounds. Food too ! Night :)
#
# not: Do You Let Your Emotional Wounds Fester? http://t.co/yDWhMgIMOE ? Powerful story andåÊword picture. via @forgivenwife
#
# real: Israeli military shoot Palestinian who injured 3 in West Bank car attack http://t.co/P9DCnuLODR via @YahooNews
#
# not: @WorldRunners @RunningRoom Day 3&amp;my wounds are looking much better. Running road rash. #summer #injury #offdishduty http://t.co/aGkWKaqgOS
#
# not: Time heals all wounds. And if it doesn't you name them something other than wounds and agree to let them stay. ????
#
# real: 2 Policemen receive bullet wounds Reports indicate 6-7 armed men attacked a police post.
#
# real: Palestinian rams car into Israeli soldiers wounding 3 http://t.co/n79BMXQKlg #EMM
#
# not: and the salt in my wounds isnt burnin any more than it used to its not that i dont feel the pain its just im not afraid of hurting anymore
#
# not: When and how does a character recover fromåÊwounds? http://t.co/ohhkuHtjXm
#
# not: What they (dentists) don't tell u is how much ur mouth will be in pain when the numbing wears off because of the puncture wounds in ur gums.
#
# not: Our wounds can so easily turn us into people we don't want to be and we hardly see it happening
#
# not: i'm sitting in the parking lot waiting to go into therapy and i'm crying and an emotional wreck and i don't want my therapist to know ????????????
#
# not: Last week we had a blast hosting Dinner &amp; a Movie Night with 'Wreck-It Ralph' on @FtCarsonPAO! @carsonmwr #TBT http://t.co/tUYPxEoBQa
#
# not: Now that IÛªve figured out how to get my music in my rental car I can take a night drive to nowhere tonight. Hopefully without a wreck.
#
# not: i'm an emotional wreck watching emmerdale fml
#
# real: Interesting in watching a train wreck while taking acid kind of way https://t.co/kM08qiWW4g
#
# not: @DukeSkywalker @facialabuse you should do a competetion between @xxxmrbootleg &amp; #ClaudioMeloni (ultimate throat penetrator) to a wreck off.
#
# real: Man faces manslaughter charges following fatal Sunday wreck | AL.c.. Related Articles: http://t.co/5xrFhdXTvX
#
# not: *is a wreck* *gives ppl lifestyle advice*
#
# not: I'm an emotional wreck someone hold me until they upload the damn video #whatstheimportantvideo
#
# not: I added a video to a @YouTube playlist http://t.co/wYtu7vIwsj Burnt Black - Nervous Wreck
#
# not: and not a wreck of uneven layers  https://t.co/Y0WE0wXQCp
#
# not: Dj d wreck cut the beat
#
# real: @Herologist i know right? It's a train wreck. You can't believe it's happening but you can't look away.
#
# real: Wreckage 'Conclusively Confirmed' as From MH370: Malaysia P